# %%
catalog = dbutils.widgets.get("catalog")
schema_prefix = dbutils.widgets.get("schema_prefix")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"USE SCHEMA {schema_prefix}_bronze")

# %%
import os

os.remove("/Volumes/tabfm_and_tsfm/marc_susagna_staging/crm_files/landing/crm_leads02.csv")

# %%
# %sql
DROP TABLE crm_bronze

# %%
import shutil

shutil.rmtree("/Volumes/tabfm_and_tsfm/marc_susagna_bronze/checkpoints/crm_bronze")
print("Removed checkpoints folder")
