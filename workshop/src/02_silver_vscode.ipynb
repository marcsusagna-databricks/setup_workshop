# %%
catalog = "tabfm_and_tsfm"
schema_prefix = "marc_susagna"
#catalog = dbutils.widgets.get("catalog")
#schema_prefix = dbutils.widgets.get("schema_prefix")

# %%
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"USE SCHEMA {schema_prefix}_bronze")
# Out:
# DataFrame[]

# %%
spark.read.table(f"{catalog}.{schema_prefix}_bronze.crm_bronze").show()
# Out:
# +-------+-----------+------------+-----------------+-------------+------------+-------------+--------------------+---------------+
# |lead_id|    company|contact_name|opportunity_value|        stage|created_date|_rescued_data| ingestion_timestamp|    source_file|
# +-------+-----------+------------+-----------------+-------------+------------+-------------+--------------------+---------------+
# |   L001|  Acme Corp|       Alice|            15000|  Prospecting|  2026-01-04|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L002|     Globex|         Bob|            32000|Qualification|  2026-01-11|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L003|    Initech|       Carol|             8500|     Proposal|  2026-01-18|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L004|   Umbrella|        Dave|           120000|   Closed Won|  2026-01-25|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L005|  Stark Inc|         Eve|            45000|  Negotiation|  2026-02-01|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L006|  Wayne Ent|       Frank|            67000|  Prospecting|  2026-02-08|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L007|     Oscorp|       Grace|            23000|  Closed Lost|  2026-02-15|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L008|    LexCorp|       Heidi|            91000|     Proposal|  2026-02-22|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L009|  Cyberdyne|        Ivan|            54000|Qualification|  2026-03-01|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L010|     Tyrell|        Judy|            37000|   Closed Won|  2026-03-08|         NULL|2026-08-04 09:16:...|crm_leads01.csv|
# |   L011|    Soylent|        Karl|            28000|  Prospecting|  2026-04-05|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L012|    Weyland|        Liam|            73000|     Proposal|  2026-04-12|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L013|      Wonka|        Mona|            19000|  Negotiation|  2026-04-19|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L014|Massive Dyn|        Nora|            55000|   Closed Won|  2026-04-26|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L015|      Hooli|       Oscar|            41000|Qualification|  2026-05-03|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L016| Pied Piper|         Pam|            62000|  Closed Lost|  2026-05-10|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L017|     Aviato|       Quinn|            11000|  Prospecting|  2026-05-17|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L018|   Prestige|        Rita|            88000|  Negotiation|  2026-05-24|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L019|     Dunder|         Sam|            34000|     Proposal|  2026-05-31|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# |   L020|      Sabre|        Tina|            46000|   Closed Won|  2026-06-07|         NULL|2026-08-04 09:20:...|crm_leads02.csv|
# +-------+-----------+------------+-----------------+-------------+------------+-------------+--------------------+---------------+
